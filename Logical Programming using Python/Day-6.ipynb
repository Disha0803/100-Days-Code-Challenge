# %%
def create():
    q=[]
    return q
def check(q):
    if len(q)==0:
        return 0
    else:
        return 1
def enqueue(q,item):
    q.append(item)
    print("Enqueued ",item)
def dequeue(q):
    if (check(q)==0):
        return "Empty q"
    return q.pop(0)

n=int(input("How many elements you want to enter into the queue: "))
print("Enter the elemnts:")
s=create()
for i in range(n):
    enqueue(s,input())
ch=0
while ch!=4:
    print("Do you want to continue?")
    print("Choose according to your choice:\n1-->enqueue\n2-->dequeue\n3-->display queue\n4-->exit")
    ch=int(input())
    if ch==1:
        print("Enter the element to enqueue:")
        enqueue(s,input())
    elif ch==2:
        dequeue(s)
    elif ch==3:
        print(s)
    elif ch==4:
        break
    else:
        print("Wrong choice")
# Out:
# How many elements you want to enter into the queue: 5
# Enter the elemnts:
# 23
# Enqueued  23
# 12
# Enqueued  12
# 21
# Enqueued  21
# 85
# Enqueued  85
# 45
# Enqueued  45
# Do you want to continue?
# Choose according to your choice:
# 1-->enqueue
# 2-->dequeue
# 3-->display queue
# 4-->exit
# 1
# Enter the element to enqueue:
# 54
# Enqueued  54
# Do you want to continue?
# Choose according to your choice:
# 1-->enqueue
# 2-->dequeue
# 3-->display queue
# 4-->exit
# 2
# Do you want to continue?
# Choose according to your choice:
# 1-->enqueue
# 2-->dequeue
# 3-->display queue
# 4-->exit
# 3
# ['12', '21', '85', '45', '54']
# Do you want to continue?
# Choose according to your choice:
# 1-->enqueue
# 2-->dequeue
# 3-->display queue
# 4-->exit
# 2
# Do you want to continue?
# Choose according to your choice:
# 1-->enqueue
# 2-->dequeue
# 3-->display queue
# 4-->exit
# 3
# ['21', '85', '45', '54']
# Do you want to continue?
# Choose according to your choice:
# 1-->enqueue
# 2-->dequeue
# 3-->display queue
# 4-->exit
# 1
# Enter the element to enqueue:
# 32
# Enqueued  32
# Do you want to continue?
# Choose according to your choice:
# 1-->enqueue
# 2-->dequeue
# 3-->display queue
# 4-->exit
# 3
# ['21', '85', '45', '54', '32']
# Do you want to continue?
# Choose according to your choice:
# 1-->enqueue
# 2-->dequeue
# 3-->display queue
# 4-->exit
# 4
